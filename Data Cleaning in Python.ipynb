# %%
import pandas as pd

# %%
df = pd.read_csv('EData.csv')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Date'] = pd.to_datetime(df['InvoiceDate']).dt.date

# %%
df = df.drop(['InvoiceDate'], axis=1)

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#         UnitPrice  CustomerID         Country        Date  Revenue
# ...

# %%
df1 = df.drop_duplicates(subset='StockCode', keep='first')
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 509369    579297    85179a              GREEN BITTY LIGHT CHAIN         1
# 512588    579512     23617  SET 10 CARDS SWIRLY XMAS TREE 17104         2
# 527065    580691    90214U            LETTER "U" BLING KEY RING        12
# 537224    581238    47591b             SCOTTIES CHILDRENS APRON         1
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
#
#         UnitPrice  CustomerID         Country        Date    Revenue
# ...

# %%
df2 = df1[['StockCode', 'Description', 'Date']]
df2
# Out:
#        StockCode                          Description        Date
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER  2010-12-01
# 1          71053                  WHITE METAL LANTERN  2010-12-01
# 2         84406B       CREAM CUPID HEARTS COAT HANGER  2010-12-01
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE  2010-12-01
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.  2010-12-01
# ...          ...                                  ...         ...
# 509369    85179a              GREEN BITTY LIGHT CHAIN  2011-11-29
# 512588     23617  SET 10 CARDS SWIRLY XMAS TREE 17104  2011-11-29
# 527065    90214U            LETTER "U" BLING KEY RING  2011-12-05
# 537224    47591b             SCOTTIES CHILDRENS APRON  2011-12-08
# 540421     23843          PAPER CRAFT , LITTLE BIRDIE  2011-12-09
#
# [4070 rows x 3 columns]

# %%
Orders = df.groupby(by="InvoiceNo")["Quantity"].sum().reset_index()
Orders.head(10)
# Out:
#   InvoiceNo  Quantity
# 0    536365        40
# 1    536366        12
# 2    536367        83
# 3    536368        15
# 4    536369         3
# 5    536370       449
# 6    536371        80
# 7    536372        12
# 8    536373        88
# 9    536374        32

# %%
df3 = df.groupby(by="InvoiceNo")["Revenue"].sum().reset_index()
df3['Date'] = df['Date']

# %%
Orders = df.groupby(by="InvoiceNo")["Quantity"].sum().reset_index()
Orders['Date'] = df['Date']
Orders.head(10)
# Out:
#   InvoiceNo  Quantity        Date
# 0    536365        40  2010-12-01
# 1    536366        12  2010-12-01
# 2    536367        83  2010-12-01
# 3    536368        15  2010-12-01
# 4    536369         3  2010-12-01
# 5    536370       449  2010-12-01
# 6    536371        80  2010-12-01
# 7    536372        12  2010-12-01
# 8    536373        88  2010-12-01
# 9    536374        32  2010-12-01

# %%
with pd.ExcelWriter('EcommerceData.xlsx') as writer: 
    df.to_excel(writer, sheet_name='Data')
    df2.to_excel(writer, sheet_name='UniqueItems')
    df3.to_excel(writer, sheet_name='InvoiceAmount')
    Orders.to_excel(writer, sheet_name='Orders')
